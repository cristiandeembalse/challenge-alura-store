# %% [markdown]
# # **Introducción**

# %% [markdown]
# #### Se presenta el desarrollo del Challenge Alura Store, un análisis de ventas y rendimiento de 4 tiendas, con el objetivo de ayudar al señor Juan a decidir qué tienda debe vender para invertir en un nuevo negocio.

# %% [markdown]
# ### **Estructura de datos**
# #### El conjunto de datos incluye información sobre:
#
# 📦 **Producto**: Identificación del producto vendido.
#
# 🏷 **Categoría**: Clasificación del producto.
#
# 💰 **Precio**: Valor de venta del producto.
#
# 💲 **Envío**: Costo del envío.
#
# 🗓 **Fecha y ubicación de compra**: Información temporal y geográfica.
#
# 👍 **Evaluación de compra**: Calificación del cliente sobre su experiencia de compra.
#
# 💳 **Tipo de Pago y Cuotas**: Métodos utilizados por los clientes.
#
# 🧭 **Coordenadas Geográficas**: Ubicación de las transacciones.

# %% [markdown]
# ### **Análisis realizados**
# 1. Análisis de facturación.
# 2. Ventas por categoría.
# 3. Cáĺculo de las calificaciones promedio por tienda.
# 4. Productos más y menos vendidos.
# 5. Envío promedio por tienda.
# 6. Generando los gráficos.
# 7. Análisis del desempeño geográfico.

# %% [markdown]
# ### **Herramientas utilizadas**
# *   Google Colab.
# *   Python.
# *   Pandas, Matplotlib, Seaborn.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# ---

# %% [markdown]
# # **1. Análisis de facturación**

# %% [markdown]
# #### *Cálculo del ingreso total de cada tienda. Se sumaron los valores de la columna Precio del conjunto de datos de cada tienda*

# %%
total_tienda = tienda['Precio'].sum()
print(total_tienda)
# Out:
# 1150880400.0

# %%
total_tienda2 = tienda2['Precio'].sum()
print(total_tienda2)
# Out:
# 1116343500.0

# %%
total_tienda3 = tienda3['Precio'].sum()
print(total_tienda3)
# Out:
# 1098019600.0

# %%
total_tienda4 = tienda4['Precio'].sum()
print(total_tienda4)
# Out:
# 1038375700.0

# %% [markdown]
# ---

# %% [markdown]
# # **2. Ventas por categoría**

# %% [markdown]
# #### *Cálculo de la cantidad de productos vendidos por categoría en cada tienda. Se agruparon los datos por categoría, contando el número de ventas de cada tipo, y mostrando las categorías más populares de cada tienda*

# %%
# Agrupa por productos vendidos, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
productos_tienda = tienda.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)

# %%
# Creamos un DataFrame y renombramos la columna para mayor claridad
categoria_tienda = productos_tienda.to_frame()
categoria_tienda.rename(columns={'Precio':'Cantidad - Tienda 1'}, inplace=True)
categoria_tienda.head()
# Out:
#                         Cantidad - Tienda 1
# Categoría del Producto
# Muebles                                 465
# Electrónicos                            448
# Juguetes                                324
# Electrodomésticos                       312
# Deportes y diversión                    284

# %%
# Agrupa por categoría, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
categoria_tienda2 = categoria_tienda2.to_frame()
categoria_tienda2.rename(columns={'Precio':'Cantidad - Tienda 2'}, inplace=True)
categoria_tienda2.head()
# Out:
#                         Cantidad - Tienda 2
# Categoría del Producto
# Muebles                                 442
# Electrónicos                            422
# Juguetes                                313
# Electrodomésticos                       305
# Deportes y diversión                    275

# %%
# Agrupa por categoría, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
categoria_tienda3 = categoria_tienda3.to_frame()
categoria_tienda3.rename(columns={'Precio':'Cantidad - Tienda 3'}, inplace=True)
categoria_tienda3.head()
# Out:
#                         Cantidad - Tienda 3
# Categoría del Producto
# Muebles                                 499
# Electrónicos                            451
# Juguetes                                315
# Electrodomésticos                       278
# Deportes y diversión                    277

# %%
# Agrupa por categoría y cuenta la cantidad de productos vendidos
categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
categoria_tienda4 = categoria_tienda4.to_frame()
categoria_tienda4.rename(columns={'Precio':'Cantidad - Tienda 4'}, inplace=True)
categoria_tienda4.head()
# Out:
#                         Cantidad - Tienda 4
# Categoría del Producto
# Muebles                                 480
# Electrónicos                            451
# Juguetes                                338
# Deportes y diversión                    277
# Electrodomésticos                       254

# %% [markdown]
# ---

# %% [markdown]
# # **3. Cáĺculo de las calificaciones promedio por tienda**

# %% [markdown]
# #### *Cálculo de las calificaciones promedio de los clientes para cada tienda*

# %%
calificacion_tienda = round(tienda['Calificación'].mean(), 2)
print(f'La calificación promedio de la Tienda 1 es: {calificacion_tienda}')
# Out:
# La calificación promedio de la Tienda 1 es: 3.98

# %%
calificacion_tienda2 = round(tienda2['Calificación'].mean(), 2)
print(f'La calificación promedio de la Tienda 2 es: {calificacion_tienda2}')
# Out:
# La calificación promedio de la Tienda 2 es: 4.04

# %%
calificacion_tienda3 = round(tienda3['Calificación'].mean(), 2)
print(f'La calificación promedio de la Tienda 3 es: {calificacion_tienda3}')
# Out:
# La calificación promedio de la Tienda 3 es: 4.05

# %%
calificacion_tienda4 = round(tienda4['Calificación'].mean(), 2)
print(f'La calificación promedio de la Tienda 4 es: {calificacion_tienda4}')
# Out:
# La calificación promedio de la Tienda 4 es: 4.0

# %% [markdown]
# ---

# %% [markdown]
# # **4. Productos más y menos vendidos**

# %% [markdown]
# #### *Identificación de los productos más vendidos y menos vendidos en cada tienda. Se visualizaron los resultados para que quede claro qué productos destacaron en ventas en cada tienda*

# %% [markdown]
# #### *Productos más vendidos de la Tienda 1*

# %%
# Agrupa por productos vendidos, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
productos_tienda = tienda.groupby('Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
productos_tienda = productos_tienda.to_frame()
productos_tienda.rename(columns={'Precio':'Cantidad - Tienda 1'}, inplace=True)
productos_tienda.head()
# Out:
#                   Cantidad - Tienda 1
# Producto
# Armario                            60
# TV LED UHD 4K                      60
# Microondas                         60
# Secadora de ropa                   58
# Mesa de noche                      56

# %% [markdown]
# #### *Productos menos vendidos de la Tienda 1*

# %%
productos_tienda.tail()
# Out:
#                            Cantidad - Tienda 1
# Producto
# Mochila                                     39
# Pandereta                                   36
# Olla de presión                             35
# Celular ABXY                                33
# Auriculares con micrófono                   33

# %% [markdown]
# #### *Productos más vendidos de la Tienda 2*

# %%
# Agrupa por productos vendidos, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
productos_tienda2 = tienda2.groupby('Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
productos_tienda2 = productos_tienda2.to_frame()
productos_tienda2.rename(columns={'Precio':'Cantidad - Tienda 2'}, inplace=True)
productos_tienda2.head()
# Out:
#                            Cantidad - Tienda 2
# Producto
# Iniciando en programación                   65
# Microondas                                  62
# Batería                                     61
# Pandereta                                   58
# Guitarra acústica                           58

# %% [markdown]
# #### *Productos menos vendidos de la Tienda 2*

# %%
productos_tienda2.tail()
# Out:
#                  Cantidad - Tienda 2
# Producto
# Auriculares                       37
# Sillón                            35
# Impresora                         34
# Mesa de comedor                   34
# Juego de mesa                     32

# %% [markdown]
# #### *Productos más vendidos de la Tienda 3*

# %%
# Agrupa por productos vendidos, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
productos_tienda3 = tienda3.groupby('Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
productos_tienda3 = productos_tienda3.to_frame()
productos_tienda3.rename(columns={'Precio':'Cantidad - Tienda 3'}, inplace=True)
productos_tienda3.head()
# Out:
#                  Cantidad - Tienda 3
# Producto
# Kit de bancas                     57
# Mesa de comedor                   56
# Cama king                         56
# Set de ollas                      55
# Mesa de noche                     55

# %% [markdown]
# #### *Productos menos vendidos de la Tienda 3*

# %%
productos_tienda3.tail()
# Out:
#                          Cantidad - Tienda 3
# Producto
# Guitarra eléctrica                        38
# Mochila                                   36
# Microondas                                36
# Set de vasos                              36
# Bloques de construcción                   35

# %% [markdown]
# #### *Productos más vendidos de la Tienda 4*

# %%
# Agrupa por productos vendidos, cuenta la cantidad de productos vendidos, y ordena de mayor a menor
productos_tienda4 = tienda4.groupby('Producto')['Precio'].count().sort_values(ascending=False)

# Crea un DataFrame y renombra la columna para mayor claridad
productos_tienda4 = productos_tienda4.to_frame()
productos_tienda4.rename(columns={'Precio':'Cantidad - Tienda 4'}, inplace=True)
productos_tienda4.head()
# Out:
#                            Cantidad - Tienda 4
# Producto
# Cama box                                    62
# Cubertería                                  59
# Cama king                                   56
# Dashboards con Power BI                     56
# Carrito de control remoto                   55

# %% [markdown]
# #### *Productos menos vendidos de la Tienda 4*

# %%
productos_tienda4.tail()
# Out:
#                              Cantidad - Tienda 4
# Producto
# Ciencia de datos con Python                   38
# Refrigerador                                  38
# Guitarra acústica                             37
# Armario                                       34
# Guitarra eléctrica                            33

# %% [markdown]
# ---

# %% [markdown]
# # **5. Envío promedio por tienda**

# %% [markdown]
# ####  *Cálculo del costo del envío promedio para cada tienda*

# %%
envio_tienda = round(tienda['Costo de envío'].mean(), 2)
print(f'El costo del envío promedio de la Tienda 1 es: {envio_tienda}')
# Out:
# El costo del envío promedio de la Tienda 1 es: 26018.61

# %%
envio_tienda2 = round(tienda2['Costo de envío'].mean(), 2)
print(f'El costo del envío promedio de la Tienda 2 es: {envio_tienda2}')
# Out:
# El costo del envío promedio de la Tienda 2 es: 25216.24

# %%
envio_tienda3 = round(tienda3['Costo de envío'].mean(), 2)
print(f'El costo del envío promedio de la Tienda 3 es: {envio_tienda3}')
# Out:
# El costo del envío promedio de la Tienda 3 es: 24805.68

# %%
envio_tienda4 = round(tienda4['Costo de envío'].mean(), 2)
print(f'El costo del envío promedio de la Tienda 4 es: {envio_tienda4}')
# Out:
# El costo del envío promedio de la Tienda 4 es: 23459.46

# %% [markdown]
# ---

# %% [markdown]
# # **6. Generando los gráficos**

# %% [markdown]
# #### *Comparativo de la facturación de las tiendas mediante un gráfico de barras verticales*

# %%
import matplotlib.pyplot as plt

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
facturacion = [1150880400.0, 1116343500, 1098019600.0, 1038375700.0]
colores = ['royalblue', 'green', 'brown', 'tomato']

# %%
plt.figure(figsize=(7, 4))
plt.bar(tiendas, facturacion, color=colores)
plt.title('Facturación de las tiendas')
plt.xlabel('Tiendas')
plt.ylabel('Facturación ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# #### *Comparativo de la calificación de los clientes mediante un gráfico de barras horizontales*

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones = [calificacion_tienda, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]
colores = ['royalblue', 'green', 'brown', 'tomato']

plt.figure(figsize=(7, 4))
plt.barh(tiendas, calificaciones, color=colores)
plt.title('Calificación promedio de la tienda')
plt.xlabel('Calificación')
plt.ylabel('Tiendas')
plt.grid(axis='x', linestyle='--', alpha=0.7)

# %% [markdown]
# ####  *Comparativo del costo del envío promedio para cada tienda*

# %%
# Datos
etiquetas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
costo_envio = [26018.61, 25216.24, 24805.68, 23459.46]

# Crear el gráfico de torta
plt.pie(costo_envio, labels=etiquetas, autopct='%1.1f%%', startangle=90)

# Establecer que el gráfico sea un círculo perfecto
plt.axis('equal')

# Título
plt.title('Envío promedio para cada tienda')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **7. Análisis del desempeño geográfico**

# %%
import seaborn as sns

# %%
tabla_tienda1 = tienda.groupby(['lat', 'lon']).size().unstack(fill_value=0)
tabla_tienda2 = tienda2.groupby(['lat', 'lon']).size().unstack(fill_value=0)
tabla_tienda3 = tienda3.groupby(['lat', 'lon']).size().unstack(fill_value=0)
tabla_tienda4 = tienda4.groupby(['lat', 'lon']).size().unstack(fill_value=0)

# %%
# Crea una figura con 4 subplots (2x2)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Heatmap para la Tienda 1
sns.heatmap(tabla_tienda1, annot=True, cmap='YlGnBu', ax=axes[0, 0])
axes[0, 0].set_title('Tienda 1')

# Heatmap para la Tienda 2
sns.heatmap(tabla_tienda2, annot=True, cmap='YlGnBu', ax=axes[0, 1])
axes[0, 1].set_title('Tienda 2')

# Heatmap para la Tienda 3
sns.heatmap(tabla_tienda3, annot=True, cmap='YlGnBu', ax=axes[1, 0])
axes[1, 0].set_title('Tienda 3')

# Heatmap para la Tienda 4
sns.heatmap(tabla_tienda4, annot=True, cmap='YlGnBu', ax=axes[1, 1])
axes[1, 1].set_title('Tienda 4')

plt.tight_layout()  # Ajusta los subplots para que no se superpongan
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **Informe final**

# %% [markdown]
# #### Para recomendar al señor Juan cuál tienda debe cerrar consideramos la evolución de la facturación anual de cada tienda, porque el mejor predictor económico del futuro es el pasado. Para ello generamos un gráfico con la facturación de las tiendas correspondiente a 2020, 2021, y 2022. Descartamos 2023 porque solo se dispone de datos de algunos meses.

# %%
anos = [2020, 2021, 2022]

# %%
tienda['Fecha de Compra'] = pd.to_datetime(tienda['Fecha de Compra'], format='%d/%m/%Y')
tienda['Año'] = tienda['Fecha de Compra'].dt.year
tienda_por_año = tienda.groupby('Año')['Precio'].sum()
facturacion_anual = [368933200.0, 362120800.0, 316565600.0]

# %%
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'], format='%d/%m/%Y')
tienda2['Año'] = tienda2['Fecha de Compra'].dt.year
tienda2_por_año = tienda2.groupby('Año')['Precio'].sum()
facturacion2_anual = [320466600.0, 351215500.0, 358226500.0]

# %%
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'], format='%d/%m/%Y')
tienda3['Año'] = tienda3['Fecha de Compra'].dt.year
tienda3_por_año = tienda3.groupby('Año')['Precio'].sum()
facturacion3_anual = [321707500.0, 362954400.0, 350438300.0]

# %%
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'], format='%d/%m/%Y')
tienda4['Año'] = tienda4['Fecha de Compra'].dt.year
tienda4_por_año = tienda4.groupby('Año')['Precio'].sum()
facturacion4_anual = [330847700.0, 347823600.0, 302221500.0]

# %%
plt.figure(figsize=(8,4))
plt.plot(anos, facturacion_anual, label='Tienda 1', color='royalblue')
plt.plot(anos, facturacion2_anual, label='Tienda 2', color='green')
plt.plot(anos, facturacion3_anual, label='Tienda 3', color='brown')
plt.plot(anos, facturacion4_anual, label='Tienda 4', color='tomato')
plt.xticks([2020, 2021, 2022])
plt.title('Evolución de la facturación anual de cada tienda')
plt.xlabel('Años')
plt.ylabel('Facturación')
plt.legend()
plt.show()

# %% [markdown]
# El señor Juan debe conservar las tiendas 2 y 3 que tienen un buen desempeño. Las tiendas 1 y 4 han disminuido su facturación. Comparando estos dos casos, vemos que los ingresos totales de la Tienda 1 fueron 1.150.880.400 pesos, mientras que los de la Tienda 2 fueron 1.038.375.700 pesos. La mayor facturación de la Tienda 1 es un dato contundente que no alcanza a compensar la Tienda 4 con su menor costo promedio de envío y mayor satisfacción a los clientes. Con lo expuesto hasta aquí se aconseja al señor Juan **vender la Tienda 4** y mejorar la atención al cliente de la Tienda 1.
